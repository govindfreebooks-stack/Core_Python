# %% [markdown]
# # **What are Python KeyError Exceptions and How to Handle Them**
#
# There are times when you have written your code but while you execute, it might not run.
#
# These types of situations occur when the input is inappropriate or you try to open a file with a wrong path or try to divide a number by zero.
#
# Due to some errors or incorrect command the output will not be displayed.
#
# This is because of errors and exceptions which are a part of the Python programming language.

# %% [markdown]
# # **What is Exception Handling?**
# Python raises exceptions when it encounters errors during execution. A Python Exception is basically a construct that signals any important event, such as a run-time error.
#
# **Exception Handling **is the process of responding to executions during computations, which often interrupts the usual flow of executing a program. It can be performed both at the software level as part of the program and also at hardware level using built-in CPU mechanisms.
#
# **Why is Exception Handling Important?**
# Although exceptions might be irritating when they occur, they play an essential role in high level languages by acting as a friend to the user.
#
# An error at the time of execution might lead to two things— either your program will die or will display a blue screen of death. On the other hand, exceptions act as communication tools. It allows the program to answer the questions — what, why and how something goes wrong and then terminates the program in a delicate manner.
#
# In simple words, exception handling protects against uncontrollable program failures and increases the potency and efficiency of your code. If you want to master yourself in programming, the knowledge of exceptions and how to handle them is very crucial, especially in Python.
#
# **What are the Errors and Exceptions in Python?**
# Python doesn’t like errors and exceptions and displays its dissatisfaction by terminating the program abruptly.
#
# There are basically two types of errors in the Python language-
#
# * Syntax Error.
#
# * Errors occuring at run-time or Exceptions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Syntax Errors**
#
# Syntax Errors, also known as parsing errors, occur when the parser identifies an incorrect statement. In simple words, syntax error occurs when the proper structure or syntax of the programming language is not followed.
#
# An example of a syntax error:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exceptions**
#
# Exceptions occur during run-time. Python raises an exception when your code has a correct syntax but it encounters a run-time issue which it is not able to handle.
#
# There are a number of defined built-in exceptions in Python which are used in specific situations. Some of the built-in exceptions are:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There are another type of built-in exceptions called warnings. They are usually issued in situations where the user is alerted of some conditions. The condition does not raise an exception; rather it  terminates the program.

# %% [markdown]
# First we look for list of Errors in Python.

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %% [markdown]
# If you run the above code you will get a list of Errors as shown below.
#
# ![image.png](data:image/png;base64,...)
#
# In this Chapter we are going to look into how we are handling Exception.

# %% [markdown]
# # **Common Exceptions**
#
# Python provides the number of built-in exceptions, but here we are describing the common standard exceptions. A list of common exceptions that can be thrown from a standard Python program is given below.
#
# **ZeroDivisionError:** Occurs when a number is divided by zero.
#
# **NameError:** It occurs when a name is not found. It may be local or global.
#
# **IndentationError:** If incorrect indentation is given.
#
# **IOError:** It occurs when Input Output operation fails.
#
# **EOFError:** It occurs when the end of the file is reached, and yet operations are being performed.

# %%
# initialize the amount variable 
#amount = 10000

# check that You are eligible to 
# get a loan or not 
if(amount>2999):
    print("You are eligible to get a loan")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       1 # initialize the amount variable
#       2 #amount = 10000
#       3
#       4 # check that You are eligible to
#       5 # get a loan or not
# ----> 6 if(amount>2999):
#       7     print("You are eligible to get a loan")
#
# NameError: name 'amount' is not defined

# %%
a = [1, 2, 3] 
print("Second element = %d" %(a[1]) )
# Throws error since there are only 3 elements in array 
print("Fourth element = %d" %(a[3]) )
# Out:
# Second element = 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 print("Second element = %d" %(a[1]) )
#       3 # Throws error since there are only 3 elements in array
# ----> 4 print("Fourth element = %d" %(a[3]) )
#
# IndexError: list index out of range

# %% [markdown]
# Try Except: This follows the below syntax:
#
# ![Capture.JPG](data:image/jpeg;base64,...)
#
# Look the below simple code.

# %%
# D16_T2_try-except statement
# Python program to handle simple runtime error 
a = [1, 2, 3] 
try: 
	print("Second element = %d" %(a[1]) )
	# Throws error since there are only 3 elements in array 
	print("Fourth element = %d" %(a[3]) )
except IndexError: 
	print("An error -IndexError - occurred")
# Out:
# Second element = 2
# An error -IndexError - occurred

# %%
# This code is to make sure that exception is there or not
try:  
    a = int(input("Enter a:"))    
    b = int(input("Enter b:"))    
    c = a/b  
except:  
    print("There is some exception occured. Please check")
    print("Can't divide with zero")
# Out:
# Enter a:5
# Enter b:2

# %% [markdown]
# **Try Except Else:**
#
# We can also use the else statement with the try-except statement in which, we can place the code which will be executed in the scenario if no exception occurs in the try block.
#
# The syntax to use the else statement with the try-except statement is given below.
#
# ![Capture.JPG](data:image/jpeg;base64,...)
#
# Look the below simple code for reference.

# %%
try:  
    a = int(input("Enter a:"))    
    b = int(input("Enter b:"))    
    c = a/b  
except:  
    print("Can't divide with zero")  
else:
  print(c)
# Out:
# Enter a:a
# Can't divide with zero

# %% [markdown]
# # **The except statement using with exception variable**
#
# We can use the exception variable with the except statement. It is used by using the as keyword. this object will return the cause of the exception. Consider the following example:

# %%
try:
    #print(10)
    #print(x)
    #print(20/0)
    a = [1, 2, 3] ; print(a[4])
except NameError:
    print("Variable x is not defined")
except ZeroDivisionError:
    print("Can't Divide with Zero")
except:
    print("Something else went wrong")
# Out:
# Something else went wrong

# %%
try:    
    #print(10)
    #print(x)
    #print(20/0)
    a = [1, 2, 3] ; print(a[4])
    # Using exception object with the except statement  
except Exception as e:    
    #print("can't divide by zero")    
    print(e)  
else:    
    print("Hi I am else block")
# Out:
# list index out of range

# %%
try:    
    #print(10)
    #print(x)
    #print(20/0)
    a = [1, 2, 3] ; print(a[4])
    # Using exception object with the except statement  
except Exception as e:    
    #print("can't divide by zero")    
    print(f"Error: {type(e).__name__}, Message: {str(e)}")  
else:    
    print("Hi I am else block")
# Out:
# Error: IndexError, Message: list index out of range

# %%
a = [1, 2, 3] ; print(a[4])

# %%
try:
    #print(10)
    #print(x)
    #print(20/0)
    a = [1, 2, 3] ; print(a[4])
except NameError:
    print("Variable x is not defined")
except ZeroDivisionError:
    print("Can't Divide with Zero")
except ValueError:
    print("You have entered non numeric")    
except IndexError:
    print("list index out of range")   
except:
    print("Something else went wrong")
# Out:
# list index out of range

# %% [markdown]
# # **The try...finally block**
#
#
# Python provides the optional finally statement, which is used with the try statement. It is executed no matter what exception occurs and used to release the external resource. The finally block provides a guarantee of the execution.
#
# We can use the finally block with the try block in which we can pace the necessary code, which must be executed before the try statement throws an exception.
#
# The syntax to use the finally block is given below.
#
# ![image.png](data:image/png;base64,...)
#
# Consider the following example:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
try:  
    a = int(input("Enter a:"))    
    b = int(input("Enter b:"))    
    c = a/b  
except:  
    print("Can't divide with zero")  
else:
  print(c)
finally:
  print("Thank you for using my program")
# Out:
# Enter a:2
# Enter b:0
# Can't divide with zero
# Thank you for using my program

# %% [markdown]
# ## Excercise for practice

# %%
# D16_T5_Try-Except-Else statement
try:
  print("Hello")
# Remove the below # to create exception
  #print(x)
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
# D16_T5_Try-Except-Else statement
try:
  print("Hello")
# Remove the below # to create exception
  print(x)
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")

# %%
# D16_T3_Multi-exception
# Define a function here.
try:
    print(10)
    #print(x)
    print(20/0)
    #a = [1, 2, 3] ; print(a[4])
except NameError:
    print("Variable x is not defined")
except ZeroDivisionError:
    print("Can't Divide with Zero")
except:
    print("Something else went wrong")

# %% [markdown]
# ## Exception Capture

# %%
# D16_T3_Multi-exception
# Define a function here.
try:
  #print(10)
  #print(x)
  #print(20/0)
  a = [1, 2, 3] ; print(a[4])
except NameError:
  print("Variable x is not defined")
except ZeroDivisionError:
  print("Can't Divide with Zero")
except Exception as e:
  print(type(e).__name__)
  print(e)
  #print("Something else went wrong")
# Out:
# IndexError
# list index out of range

# %% [markdown]
# ## User Defined Exception
#
# ### Using Raise and Assert

# %%
age = int(input("Enter the age:"))    
if(age<18):    
    raise ValueError
# Out:
# Enter the age:2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 age = int(input("Enter the age:"))
#       2 if(age<18):
# ----> 3     raise ValueError
#
# ValueError:

# %%
age = int(input("Enter the age:"))    
if(age<18):    
    raise ValueError("Only persons with age above 18 are allowed")
# Out:
# Enter the age:2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 age = int(input("Enter the age:"))
#       2 if(age<18):
# ----> 3     raise ValueError("Only persons with age above 18 are allowed")
#
# ValueError: Only persons with age above 18 are allowed

# %%
try:    
    age = int(input("Enter the age:"))    
    if(age<18):    
        raise ValueError       
except ValueError:    
    print("The age is not valid for Voting")    
else:    
    print("the age is valid for Voting")
# Out:
# Enter the age:2
# The age is not valid for Voting

# %%
# D16_T7_Raise_Example statement
x = "hello"
#x=2

if not type(x) is int:
  raise Type1Error("Only integers are allowed")

# %% [markdown]
# ## assert Exception

# %%
# D16_T8_Assert_Example statement
def KelvinToFahrenheit(Temperature):
   assert (Temperature >= 0),"Colder than absolute zero!"
   return ((Temperature-273)*1.8)+32

print (KelvinToFahrenheit(273))
print (int(KelvinToFahrenheit(505.78)))
print (KelvinToFahrenheit(-5))
# Out:
# 32.0
# 451
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 8
#       6 print (KelvinToFahrenheit(273))
#       7 print (int(KelvinToFahrenheit(505.78)))
# ----> 8 print (KelvinToFahrenheit(-5))
#
# Cell In[21], line 3, in KelvinToFahrenheit(Temperature)
#       2 def KelvinToFahrenheit(Temperature):
# ----> 3    assert (Temperature >= 0),"Colder than absolute zero!"
#       4    return ((Temperature-273)*1.8)+32
#
# AssertionError: Colder than absolute zero!

# %% [markdown]
# When an exception occurs, it may have an associated value, also known as the exception’s argument. The presence and type of the argument depend on the exception type.
#
# The except clause may specify a variable after the exception name. The variable is bound to an exception instance with the arguments stored in instance.args. For convenience, the exception instance defines __str__() so the arguments can be printed directly without having to reference .args. One may also instantiate an exception first before raising it and add any attributes to it as desired.

# %%
# D16_T7_b_Raise_Example
trafic_volume = 200
try:
    if trafic_volume >=100:
        raise Exception('Source_PC', 'Dest_PC')
except Exception as inst:
     print(type(inst))    # the exception instance
     print(inst.args)     # arguments stored in .args
     print(inst)          # __str__ allows args to be printed directly,
                          # but may be overridden in exception subclasses
     x, y = inst.args     # unpack args
     print('x =', x)
     print('y =', y)
# Out:
# <class 'Exception'>
# ('Source_PC', 'Dest_PC')
# ('Source_PC', 'Dest_PC')
# x = Source_PC
# y = Dest_PC

# %% [markdown]
# If an exception has arguments, they are printed as the last part (‘detail’) of the message for unhandled exceptions.

# %% [markdown]
# Exception handlers don’t just handle exceptions if they occur immediately in the try clause, but also if they occur inside functions that are called (even indirectly) in the try clause. For example:

# %%
def this_fails():
    x = 1 / 0

# %%
# calling the function result error
this_fails()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 # calling the function result error
# ----> 2 this_fails()
#
# Cell In[23], line 2, in this_fails()
#       1 def this_fails():
# ----> 2     x = 1 / 0
#
# ZeroDivisionError: division by zero

# %%
def this_fails():
    x = 1 / 0

try:
    this_fails()
except ZeroDivisionError as err:
    print('Handling run-time error:', err)
# Out:
# Handling run-time error: division by zero

# %% [markdown]
# # **Raising Exceptions¶**
# The raise statement allows the programmer to force a specified exception to occur. For example:

# %%
try:  
     num = int(input("Enter a positive integer: "))  
     if(num <= 0):
        raise ValueError("That is  a negative number!")
# Out:
#   Cell In[34], line 4
#     raise ValueError("That is  a negative number!")
#                                                      ^
# SyntaxError: incomplete input

# %%
try:  
     num = int(input("Enter a positive integer: "))  
     if(num <= 0):  
# we can pass the message in the raise statement  
         raise ValueError("That is  a negative number!")  
except ValueError as e:  
     print(e)
# Out:
# Enter a positive integer: -2
# That is  a negative number!

# %%
try:    
    a = int(input("Enter a:"))    
    b = int(input("Enter b:"))    
    if b == 0:    
        raise ArithmeticError  
    else:    
        print("a/b = ",a/b)    
except ArithmeticError:    
    print("The value of b can't be 0")
# Out:
# Enter a:1
# Enter b:0
# The value of b can't be 0

# %% [markdown]
# ### Raise error with or without message/arguments

# %%
#Raise error with message
raise NameError('HiThere')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 #Raise error with message
# ----> 2 raise NameError('HiThere')
#
# NameError: HiThere

# %%
#Raise error without message
raise ValueError  # shorthand for 'raise ValueError()'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 #Raise error without message
# ----> 2 raise ValueError
#
# ValueError:

# %%
try:
  raise NameError('HiThere')
except NameError:
  print('An exception flew by!')
  #raise
# Out:
# An exception flew by!

# %%
try:
    x=int(input('Enter a number upto 100: '))
    if x > 100:
        raise ValueError(x)
except ValueError:
    print(x, "is out of allowed range")
else:
    print(x, "is within the allowed range")
# Out:
# Enter a number upto 100: 102
# 102 is out of allowed range
