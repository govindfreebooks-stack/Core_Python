# %% [markdown]
# ### Python Data Structure

# %% [markdown]
# ![image.png](attachment:85b1c420-0fc5-4f91-8acc-1094b9e5eb04.png)

# %% [markdown]
# Python is free and open-source, which provides accountability for core developers, an enormous
# support base, and the ability for Python users to both inspect and improve its codebase. The Python
# Package Index hosts over 100 thousand Python packages that extend Python’s base functionality
# and make it very easy to set up a Python environment to tackle virtually any programming problem.
# Software in the Python Package Index can be added to a Python installation using its package
# management tool, called “pip.” Python is cross-platform, meaning it supports Windows, Mac OS, and
# Linux. Python’s primary competitors in the instrument control space require the purchase of licenses
# for the base environment and additional licenses to do unlock additional capabilities. Python requires
# no licensing and can be installed and configured very easily. Python is easy to learn, and its syntax and
# structure is very human and intuitive. Many Python users describe the experience of programming in
# Python as writing pseudocode that actually runs.

# %%
print("Hello World!")

# %%
name = input("Enter your Name")
print("Hello ", name)

# %%
3+4*5

# %%
Manpower=12
manpower =2
print("Manpower = ",Manpower)
print("manpower = ",manpower)
# Out:
# Manpower =  12
# manpower =  2

# %%
And = 12
And
# Out:
# 12

# %% [markdown]
# ### Multiple Line Statement

# %%
item1 ,item2 , item3 =10,15,20

# %%
total = item1 +  item2 +  item3
total
# Out:
# 45

# %%
total = item1 + \
        item2 + \
        item3
total
# Out:
# 45

# %%
day = ["Monday","Tuesday",
       "Wednesday","Thursday",
       "Friday","Saturday",
       "Sunday"]
day
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
word = 'abc'
sentense = "This is Gopi's House"
paragraph = '''This is a paragraph. 
                It is made up 	
                of multiple lines and sentences. He shouted "Hola". No respose from the croud'''
print(word)
print(sentense)
print(paragraph)
# Out:
# abc
# This is Gopi's House
# This is a paragraph.
#                 It is made up
#                 of multiple lines and sentences. He shouted "Hola". No respose from the croud

# %% [markdown]
# ### Python Syntax

# %%
# This is comment
print("This # is not a comment")
# Out:
# This # is not a comment

# %%
a = input("Enter your name")   # Used to collect user input
print(a)                       # Used to provide computer output
# Out:
# Enter your nameGopi
# Gopi

# %% [markdown]
# ### Multiple Statements on a Single Line

# %%
a=1;b=2;c=3;print(a+b+c)
# Out:
# 6

# %% [markdown]
# #### Multiple Statement Groups as Suites

# %%
a = int(input("Enter a number"))
if a > 10:
    print("a is greater that 10")
    print("a is not equal to 10")
    print("a is not less than 10")
    
else:
    print("a is not greater than 10")
    print("a may be equal to 10")
    print("a may be less than 10")
# Out:
# Enter a number2
# a is not greater than 10
# a may be equal to 10
# a may be less than 10

# %%
# Assigning Values to Variables
counter = 100          # An integer assignment
miles   = 1000.0       # A floating point
name    = "123"       # A string

print(counter)
print(miles)
print(name)
# Out:
# 100
# 1000.0
# 123

# %%
print(type(counter))
print(type(miles))
print(type(name))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# Multiple Assignment
a = b = c = 1
print("a = ",a)
print("b = ",b)
print("c = ",c)
# Out:
# a =  1
# b =  1
# c =  1

# %%
x,y,z = 1,2,"john"
print("x = ",x)
print("y = ",y)
print("z = ",z)
# Out:
# x =  1
# y =  2
# z =  john

# %%
var1 = 1
var2 = 10
print(var1)
print(var2)

del var1,var2 # delete the above variables
#print(var1)   # This will result error if you remove #
#print(var2)   # This will result error if you remove #
# Out:
# 1
# 10

# %% [markdown]
# ## String Data Type

# %%
# Python Strings
str = 'Hello World!'
print(str)          # Prints complete string
# Out:
# Hello World!

# %% [markdown]
# ![image.png](attachment:b89a90bb-bec2-44bb-82ab-da986729b717.png)

# %%
str = 'Roses are red'

# %%
print(str[0])       # Prints first character of the string
# Out:
# R

# %%
# [Begin:stop:step]
print(str[6:12:2])
# Out:
# aer

# %%
# [Begin:stop]
str[1:5]
# Out:
# 'oses'

# %%
# It prints all the values
str[:]
# Out:
# 'Roses are red'

# %% [markdown]
# ![image.png](attachment:2b780426-c680-4125-9313-c3b73c6e8c4f.png)

# %%
str = "Patty Lynn Smith"

# %%
str[-1]
# Out:
# 'h'

# %%
str[-4]
# Out:
# 'm'

# %%
str[::-1]
# Out:
# 'htimS nnyL yttaP'

# %%
first_name = str[0:5]
first_name
# Out:
# 'Patty'

# %%
last_name = str[11:]
last_name
# Out:
# 'Smith'

# %%
middle_name = str[6:10]
middle_name
# Out:
# 'Lynn'

# %%
print(str[2:5])     # Prints characters starting from 3rd to 5th
# Out:
# tty

# %%
print(str[2:])      # Prints string starting from 3rd character
# Out:
# tty Lynn Smith

# %%
print(str * 2)      # Prints string two times
# Out:
# Patty Lynn SmithPatty Lynn Smith

# %%
print(str + " "+"TEST") # Prints concatenated string
# Out:
# Patty Lynn Smith TEST

# %%
str[-7:-11:-1]
# Out:
# 'nnyL'

# %% [markdown]
# ## List Data Type

# %%
# Python Lists
list = [ 'abcd', 786 , 2.23, 'john', 70.2 ]
tinylist = [123, 'john']

# %%
print(list)            # Prints complete list
# Out:
# ['abcd', 786, 2.23, 'john', 70.2]

# %%
print(list[0])         # Prints first element of the list
# Out:
# abcd

# %%
print(list[2:5])       # Prints elements starting from 3rd to 5th
# Out:
# [2.23, 'john', 70.2]

# %%
print(list[2:])        # Prints list starting from 3rd element
# Out:
# [2.23, 'john', 70.2]

# %%
print(tinylist * 2)        # Prints list two times
# Out:
# [123, 'john', 123, 'john']

# %%
print(list + tinylist) # Prints concatenated list & tinylist
# Out:
# ['abcd', 786, 2.23, 'john', 70.2, 123, 'john']

# %% [markdown]
# ## Tuples Data Type

# %%
# Python Tuples
tuple = ( 'abcd', 786 , 2.23, 'john', 70.2  )
tinytuple = (123, 'john')

# %%
print(tuple)            # Prints complete tuple
# Out:
# ('abcd', 786, 2.23, 'john', 70.2)

# %%
print(tuple[0])         # Prints first element of the tuple
# Out:
# abcd

# %%
print(tuple[2:5])       # Prints elements starting from 3rd to 5th
# Out:
# (2.23, 'john', 70.2)

# %%
print(tuple[2:])        # Prints tuple starting from 3rd element
# Out:
# (2.23, 'john', 70.2)

# %%
print(tinytuple * 2)        # Prints tuple two times
# Out:
# (123, 'john', 123, 'john')

# %%
print(tuple + tinytuple) # Prints concatenated tuple & tinytuple
# Out:
# ('abcd', 786, 2.23, 'john', 70.2, 123, 'john')

# %%
# Tuple is read only
print(tuple)
# Out:
# ('abcd', 786, 2.23, 'john', 70.2)

# %%
tuple[0] =1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 tuple[0] =1
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(tuple)
# Out:
# ('abcd', 786, 2.23, 'john', 70.2)

# %%
# List can be updated (write enabled)
print(list)
# Out:
# ['abcd', 786, 2.23, 'john', 70.2]

# %%
list[1] ="ABCD"

# %%
print(list)
# Out:
# ['abcd', 'ABCD', 2.23, 'john', 70.2]

# %% [markdown]
# ## dictionary Data Type

# %%
dict = {}

# %%
dict['one'] = "This is one"

# %%
dict[2]     = "This is two"

# %%
dict
# Out:
# {'one': 'This is one', 2: 'This is two'}

# %%
print(dict['one'])       # Prints value for 'one' key
# Out:
# This is one

# %%
print(dict[2])           # Prints value for 2 key
# Out:
# This is two

# %%
tinydict = {'name': 'john','code':6734, 'dept': 'sales'}

# %%
print(tinydict)          # Prints complete dictionary
# Out:
# {'name': 'john', 'code': 6734, 'dept': 'sales'}

# %%
print(tinydict['name'])
# Out:
# john

# %%
print(tinydict.keys())   # Prints all the keys
# Out:
# dict_keys(['name', 'code', 'dept'])

# %%
print(tinydict.values()) # Prints all the values
# Out:
# dict_values(['john', 6734, 'sales'])

# %% [markdown]
# ## Number Data Type

# %%
x = 1 # int
y = 2.8 # float
z = 1j # complex

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#convert from int to float:
a = float(x)
#convert from float to int:
b = int(y)
#convert from int to complex:
c = complex(x)

# %%
print(a)
print(b)
print(c)
# Out:
# 1.0
# 2
# (1+0j)

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
z = 3+1j # complex

# %%
z.real
# Out:
# 3.0

# %%
z.imag
# Out:
# 1.0

# %%
z = 3+1j # complex
# Extract and convert the real part
real_as_int = int(z.real)
real_as_int
# Out:
# 3

# %%
z = 3 + 4j
imaginary_as_real = z.imag  # This is 4.0 (a float)
print(imaginary_as_real)
# Out:
# 4.0

# %%
z = 3+1j # complex
print(z.real) 
print(z.imag)
# Out:
# 3.0
# 1.0

# %%
a = int(imaginary_as_real)
a
# Out:
# 4

# %%
int(z.imag)
# Out:
# 1

# %%
# Convert string into Integer or any other numeric type provided it contains only numbers
int("1230")
# Out:
# 1230

# %% [markdown]
# ### Changing a shared list

# %%
a = [1,2,3]
b = a
a.append(4)
print(a,b)
# Out:
# [1, 2, 3, 4] [1, 2, 3, 4]

# %%
print(id(a))
print(id(b))
# Out:
# 2713170119552
# 2713170119552

# %%
a = [1,2,3]
b = a.copy()

# %%
print(id(a))
print(id(b))
# Out:
# 2713169964032
# 2713160039296

# %%
a.append(4)
print(a,b)
# Out:
# [1, 2, 3, 4] [1, 2, 3]

# %% [markdown]
# ### Different behaviour for Numbers (than list)

# %%
a =1
b = a
print(a,b)
print("-"*15+"Before Change"+"-"*15)
a = a +1
print(a,b)
# Out:
# 1 1
# ---------------Before Change---------------
# 2 1

# %% [markdown]
# ### Python allows Swapping of Variables with out temp variable

# %%
x = 5
y = 10
print(x,y)
x,y = y,x
print(x,y)
# Out:
# 5 10
# 10 5

# %% [markdown]
# #### Swapping of Variables with temp variable

# %%
x = 5
y = 10
print(x,y)
temp = y
y = x
x = temp 
print(x,y)
# Out:
# 5 10
# 10 5

# %% [markdown]
# #### Swapping of Variables with out temp variable

# %%
x = 5; y = 10
print(x,y)
x,y = y,x
print(x,y)
# Out:
# 5 10
# 10 5

# %% [markdown]
# ### Python allows Swapping of Variables with out temp variable

# %%
# Python program to swap two variables
# Using a temporary variable
x = 5
y = 10

# To take inputs from the user
#x = input('Enter value of x: ')
#y = input('Enter value of y: ')
print('The value of x before swapping: {}'.format(x))
print('The value of y before swapping: {}'.format(y))
# create a temporary variable and swap the values
temp = x
x = y
y = temp
print('The value of x after swapping: {}'.format(x))
print('The value of y after swapping: {}'.format(y))
# Python program to swap two variables
# With out Using a temporary variable
# Out:
# The value of x before swapping: 5
# The value of y before swapping: 10
# The value of x after swapping: 10
# The value of y after swapping: 5

# %%
x = 5
y = 10
print('The value of x before swapping: {}'.format(x))
print('The value of y before swapping: {}'.format(y))
# The following code swapping but without the use of any temporary variable.
x, y = y, x
print('The value of x after swapping: {}'.format(x))
print('The value of y after swapping: {}'.format(y))
# Out:
# The value of x before swapping: 5
# The value of y before swapping: 10
# The value of x after swapping: 10
# The value of y after swapping: 5

# %% [markdown]
# ### Naresh Doubt Clear -01

# %%
str = 'Hello World!\n'
#str = 'Hello World!'

# %%
print(str * 2)      # Prints string two times
# Out:
# Hello World!
# Hello World!

# %%
name = 'Gopi'
f'Hello, {name}'
# Out:
# 'Hello, Gopi'

# %%
print('The value of x before swapping: {0} and The value of y after swapping: {1}'.format(x,y))
# Out:
# The value of x before swapping: 10 and The value of y after swapping: 5

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print(name,age)
# Out:
# Enter your name: Gopi
# Enter your age: 24
# Gopi 24

# %%
print ('name = {0} and age = {1}'.format(name,age))
# Out:
# name = Gopi and age = 24

# %%
#name, age = 'tom', 30

print(f'{name=}  and {age=}')
# name=tom age=30
# Out:
# name='Gopi'  and age='24'

# %%
name, age = 'tom', 30
print(f'{name=}  \n{age=}')
# Out:
# name='tom'
# age=30
