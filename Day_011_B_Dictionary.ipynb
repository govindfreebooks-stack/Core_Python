# %% [markdown]
# # Python Dictionary from Scratch!!!

# %% [markdown]
# ## Let us understand the fundamentals of dictionaries in python.

# %% [markdown]
# ![image.png](attachment:06c05994-1b29-4e27-8ece-e87c21176f5b.png)

# %% [markdown]
# ![image.png](attachment:40bd5b9c-0f44-4cdc-bb45-64102e1dbfc0.png)

# %% [markdown]
# ![image.png](attachment:efb1add7-cd16-44f0-a447-7214bd879da6.png)

# %%
# Declaring a dictionary (can be empty)- Method-01
dictionary1 = {}
dictionary1
# Out:
# {}

# %%
type(dictionary1)
# Out:
# dict

# %%
dictionary1[1] ="A"
dictionary1[2] ="B"
dictionary1
# Out:
# {1: 'A', 2: 'B'}

# %%
# Declaring a dictionary with keys:values- Method-02
dictionary2 = {'Name': 'Tanu', 'Class': 'First', 'Age': 8}
print(dictionary2)
# Out:
# {'Name': 'Tanu', 'Class': 'First', 'Age': 8}

# %%
type(dictionary2)
# Out:
# dict

# %%
# D11_T1_Access Values in Dictionary
dict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}

# %%
dict['Class']
# Out:
# 'First'

# %%
dict['Age']
# Out:
# 7

# %%
print("dict['Name']: ", dict['Name'])
print("dict['Age']: ", dict['Age'])
# Out:
# dict['Name']:  Zara
# dict['Age']:  7

# %% [markdown]
# ### Update and Add new Entry

# %%
dict['Age'] = 8 # update existing entry
dict['Age']
# Out:
# 8

# %%
dict['Age']  = dict['Age'] +1

# %%
dict['Age']
# Out:
# 9

# %%
dict
# Out:
# {'Name': 'Zara', 'Age': 9, 'Class': 'First'}

# %%
dict['School'] = "DPS School" # Add new entry

# %%
dict['School']
# Out:
# 'DPS School'

# %%
print("dict['Age']: ", dict['Age'])
print("dict['School']: ", dict['School'])
# Out:
# dict['Age']:  9
# dict['School']:  DPS School

# %%
dict
# Out:
# {'Name': 'Zara', 'Age': 9, 'Class': 'First', 'School': 'DPS School'}

# %% [markdown]
# ---

# %% [markdown]
# # 1) Accessing the elements in a dictionary
#
# Dictionaries can be accessed by their index to get the value. To do this, all you have to do is just place the number or the name of the key inside the pair of square brackets along with the name of the dictionary.

# %%
# Accessing the elements in a dictionary
dictionary = {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23}
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23}

# %%
dictionary['Age']
# Out:
# 23

# %%
print(dictionary['Name'])
# Out:
# Tanu

# %%
print(dictionary['Sex'])
# Out:
# Male

# %% [markdown]
# If you try to access the key which is not declared in the dictionary then an exception would be raised indicating no results found:

# %%
dictionary['Height']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 dictionary['Height']
#
# KeyError: 'Height'

# %%
check1 = 'Height'
if check1 in dictionary:
    print("Found")
    print(dictionary[check1])
else:
    print(check1, "is not Found")
# Out:
# Height is not Found

# %% [markdown]
# ### Get method
# Also, we can use the get() of the dictionary to get or access the values of the dictionary as seen below:

# %%
print(dictionary.get('Age'))
# Out:
# 23

# %%
print(dictionary.get('Height'))
# Out:
# None

# %% [markdown]
# ---

# %% [markdown]
# # 2) Removing the elements from a dictionary.
#
# In python, there are four different ways or methods that can be used to remove an element from a dictionary. Those are pop, del, popitem and clear. The del is used to delete a key from a dictionary, the pop is used to remove a specific key from a dictionary, popitem is used to remove the key arbitrarily from a dictionary, and the clear is used to just clear or delete all the elements in the dictionary (as the name suggests).

# %%
# Removing the elements from a dictionary
dictionary = {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
# Deleting an element
del dictionary['Sex']
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
# Popping an item
print(dictionary.popitem())
# Out:
# ('Occupation', 'Student')

# %%
dictionary
# Out:
# {'Name': 'Tanu', 'Age': 23, 'Height': 5.8}

# %%
# Popping the value
print(dictionary.pop('Age'))
# Out:
# 23

# %%
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Height': 5.8}

# %%
# Clearing the entire dictionary
dictionary.clear()
print(dictionary)
# Out:
# {}

# %%
del dictionary

# %%
print(dictionary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(dictionary)
#
# NameError: name 'dictionary' is not defined

# %% [markdown]
# # 3) Iterating Through a Dictionary
#
# Using a for loop we can iterate through each key in a dictionary as shown below:

# %%
dictionary = {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
key = "Name"
dictionary[key]
# Out:
# 'Tanu'

# %%
# Iterating through the keys
for key in dictionary:
    print(key)
# Out:
# Name
# Sex
# Age
# Height
# Occupation

# %%
# Iterating through the values
for key in dictionary:
    print(dictionary[key])
# Out:
# Tanu
# Male
# 23
# 5.8
# Student

# %%
# Iterating through the keys & Value pair
for key in dictionary:
    print(key,":",dictionary[key])
# Out:
# Name : Tanu
# Sex : Male
# Age : 23
# Height : 5.8
# Occupation : Student

# %%
# D11_T5_looping thro Dictionary values
people = {
    'htanaka': 'Haru Tanaka',
    'ppatel': 'Priya Patel',
    'bagarcia': 'Benjamin Alberto Garcia',
    'zmin': 'Zhang Min',
    'afarooqi': 'Ayesha Farooqi',
    'hajackson': 'Hanna Jackson',
    'papatel': 'Pratyush Aarav Patel',
    'hrjackson': 'Henry Jackson'
    }

# %%
# Count the number of key:value pairs and put in a variable.
howmany = len(people)
# Show how many.
print(howmany)
# Out:
# 8

# %%
# Change the value of the hrjackson key.
people.update({'hrjackson':'Henrietta Jackson'})
#print(people)
# Update the dictionary with a new property:value pair.
people.update({'wwiggins':'Wanda Wiggins'})
# Show what's in the data dictionary now.

# %%
len(people)
# Out:
# 9

# %%
for person in people.keys():
    print(person + " : " + people[person])
# Out:
# htanaka : Haru Tanaka
# ppatel : Priya Patel
# bagarcia : Benjamin Alberto Garcia
# zmin : Zhang Min
# afarooqi : Ayesha Farooqi
# hajackson : Hanna Jackson
# papatel : Pratyush Aarav Patel
# hrjackson : Henrietta Jackson
# wwiggins : Wanda Wiggins

# %%
#---Printing only keys----------------
for person in people:
    print(person)  # --> this will print all the keys
# Out:
# htanaka
# ppatel
# bagarcia
# zmin
# afarooqi
# hajackson
# papatel
# hrjackson
# wwiggins

# %%
#-----Printing only values------------------
for person in people:
    print(people[person])  # --> this will print all the values
# Out:
# Haru Tanaka
# Priya Patel
# Benjamin Alberto Garcia
# Zhang Min
# Ayesha Farooqi
# Hanna Jackson
# Pratyush Aarav Patel
# Henrietta Jackson
# Wanda Wiggins

# %% [markdown]
# ---

# %% [markdown]
# # 4) All
#
# The all () in dictionary returns "True" if all keys of the dictionary are true (or if the dictionary is empty). If the keys in the dictionary are true or if the dictionary all method returns true or else it will return false.

# %%
dictionary = {0: "Tanu", 1: "Prabhu"}
print(dictionary)
# Out:
# {0: 'Tanu', 1: 'Prabhu'}

# %%
print(all(dictionary))
# Out:
# False

# %%
dictionary = {1: "Tanu", 2: "Prabhu"}
print(all(dictionary))
# Out:
# True

# %%
dictionary = {}
print(all(dictionary))
# Out:
# True

# %%
users = [
    {"name": "Alice", "active": True},
    {"name": "Bob", "active": True},
    {"name": "Charlie", "active": False},
]

if all(user["active"] for user in users):
    print("Everyone's active!")
else:
    print("Some users are inactive.")
# Out:
# Some users are inactive.

# %% [markdown]
# ---

# %% [markdown]
# # 5) Any
# The any () in dictionary return "True" if any key of the dictionary is true. If the dictionary is empty, returns "False".

# %%
dictionary = {0: "Tanu", 1: "Prabhu"}
print(dictionary)
# Out:
# {0: 'Tanu', 1: 'Prabhu'}

# %%
print(any(dictionary))
# Out:
# True

# %%
dictionary = {0: "Tanu", 0: "Prabhu"}
print(any(dictionary))
# Out:
# False

# %%
# 0 is False
dictionary = {0: "Tanu"}
print(any(dictionary))
# Out:
# False

# %%
dictionary = {}
print(any(dictionary))
# Out:
# False

# %%
users = [
    {"name": "Alice", "active": False},
    {"name": "Bob", "active": False},
    {"name": "Charlie", "active": True},
]

if any(user["active"] for user in users):
    print("At least one user is active.")
else:
    print("No active users.")
# Out:
# At least one user is active.

# %% [markdown]
# ---

# %% [markdown]
# # 6) Len
# The length () method in the dictionary returns the length of the dictionary (obviously). It returns the number of items of the dictionary.

# %%
dictionary = {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
print(len(dictionary))
# Out:
# 5

# %% [markdown]
# ---

# %% [markdown]
# # 7) Sorted
# The Sorted() method in dictionary returns a new sorted list of keys in the dictionary.

# %%
dictionary = {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
# Sorting in a ascending order. Default reverse = False
print(sorted(dictionary))
# Out:
# ['Age', 'Height', 'Name', 'Occupation', 'Sex']

# %%
# Sorting in a descending order
print(sorted(dictionary, reverse = True))
# Out:
# ['Sex', 'Occupation', 'Name', 'Height', 'Age']

# %%
print(sorted(dictionary, reverse = False))
# Out:
# ['Age', 'Height', 'Name', 'Occupation', 'Sex']

# %% [markdown]
# The sorted() method accepts a reverse parameter as an optional argument.
#
# ---

# %% [markdown]
# # 8) Copy
# As the name suggests the copy method in dictionary returns a copy of the dictionary.

# %%
dictionary = {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
dictionary1 = {}
print(dictionary1)
# Out:
# {}

# %%
dictionary1 = dictionary.copy()
print(dictionary1)
# Out:
# {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
dictionary["Age"] =30

# %%
dictionary
# Out:
# {'Name': 'Tanu',
#  'Sex': 'Male',
#  'Age': 30,
#  'Height': 5.8,
#  'Occupation': 'Student'}

# %%
dictionary1
# Out:
# {'Name': 'Tanu',
#  'Sex': 'Male',
#  'Age': 23,
#  'Height': 5.8,
#  'Occupation': 'Student'}

# %%
#id(variable_name)
id(dictionary)
# Out:
# 2536481997504

# %%
id(dictionary1)
# Out:
# 2536465963648

# %% [markdown]
# ---

# %% [markdown]
# # 9) Keys
# Python dictionary method key() returns a list of all the available keys in the dictionary.

# %%
dictionary = {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}
print(dictionary)
# Out:
# {'Name': 'Tanu', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
print(dictionary.keys())
# Out:
# dict_keys(['Name', 'Sex', 'Age', 'Height', 'Occupation'])

# %% [markdown]
# ---

# %% [markdown]
# # 10) Values
# Python dictionary method values() returns a list of all the values available in a given dictionary.

# %%
dictionary = {'Name': 'Tarun', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}
print(dictionary)
# Out:
# {'Name': 'Tarun', 'Sex': 'Male', 'Age': 23, 'Height': 5.8, 'Occupation': 'Student'}

# %%
print(dictionary.values())
# Out:
# dict_values(['Tarun', 'Male', 23, 5.8, 'Student'])

# %% [markdown]
# ### dictinary fromkeys() example

# %%
keys = ['Ram', 'Babu', 'Ravi']
new_dict = dict.fromkeys(keys, 0)
print(new_dict)
# Out:
# {'Ram': 0, 'Babu': 0, 'Ravi': 0}

# %% [markdown]
# ### dictinary setdefault() example

# %%
# ✅ Example 1: Key exists
my_dict = {'a': 1, 'b': 2}
result = my_dict.setdefault('b', 100)
print(result)        # Output: 2 (the value of key b)
print(my_dict)       # Output: {'a': 1, 'b': 2}
# Out:
# 2
# {'a': 1, 'b': 2}

# %%
# ✅ Example 2: Key does not exist
my_dict = {'a': 1, 'b': 2}
result = my_dict.setdefault('c', 300)
print(result)        # Output: 300
print(my_dict)       # Output: {'a': 1, 'b': 2, 'c': 300}
# Out:
# 300
# {'a': 1, 'b': 2, 'c': 300}

# %%
# ✅ Example 3: Without providing default value
my_dict = {}
value = my_dict.setdefault('x')
print(value)         # Output: None
print(my_dict)       # Output: {'x': None}
# Out:
# None
# {'x': None}

# %% [markdown]
# #### dictinary update() example
#
# ![image.png](attachment:660a2f2a-f183-4cba-9fe4-d6d0514de2ec.png)

# %%
# ✅ Example 1: Update with another dictionary
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}

dict1.update(dict2)
print(dict1)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
# ✅ Example 2: Update with a list of tuples
my_dict = {'x': 10}
my_dict.update([('y', 20), ('z', 30)])
print(my_dict)
# Out:
# {'x': 10, 'y': 20, 'z': 30}

# %%
# ✅ Example 3: Update using keyword arguments
info = {'name': 'Alice'}
info.update(age=25, city='New York')
print(info)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %% [markdown]
# #### dictinary fromkeys() example

# %% [markdown]
# #### dictinary fromkeys() example

# %% [markdown]
# ![image.png](attachment:afe68c51-ca0d-4d5f-b7f2-71cc468b6aa3.png)

# %% [markdown]
# ---

# %% [markdown]
# Hence above are the very important techniques or functions of Dictionary in Python. Some of the examples were referred from [Python Dictionary](https://www.programiz.com/python-programming/dictionary). I have written this tutorial in a simple way such that everybody can understand and master the concepts of Dictionaries in Python without prior programming knowledge or experience. If you guys have some doubts in the code, the comment section is all yours. Thank you have a good day.
